# %%
import pickle, random, os

import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mm4me\\OneDrive\\Documents\\U Chicago MScA\\Capstone\\code'

# %%
path = 'C:\\Users\\mm4me\\OneDrive\\Documents\\U Chicago MScA\\Capstone\\'

# %%
b_r_f = pd.read_csv(path+"data\\business_r_and_f.csv", index_col="business_id")

# %%
r_ph_lv = pd.read_csv(path+"data\\r_ph_lv.csv", index_col="review_id")

# %%
r_ph_lv[(r_ph_lv.user_id == "-hJ9Q0OSYqdOTVBLOMdg7A") & (r_ph_lv.city == "Las Vegas")]
# Out:
#                                    business_id  cool        date  funny  \
# review_id
# BoguEYl3yC1bVU0KjdRqIw  NG2mL-wQQfBdsXsyUbw8pA     0  2018-01-19      0
# o8F3m8mQiuWYTbJEmFIyyw  pomGBqfbxcqPv14c3XH-ZQ     0  2016-10-07      3
# e96mj8MSNvJ3OWoA_90x9Q  Lau3N654yNyWdIIybea1uA     0  2007-05-13      0
# gGtN0IzeSh-BBmIcRNMJfQ  qJEtXdrOQeo9py0Wqr6LKQ     0  2018-03-10      0
# o9RCF0g9MWHYwnj02MfYfQ  UDE4VL0k8Zrko7RkJ4agGQ     0  2018-05-06      0
# Cd7CAMibHCl-pKklvzVBeQ  FNe5PPA9pyj8FjcDefCBpg     0  2014-12-26      0
# K_Egq7OwwNZI-RigEPJsVw  2iTsRqUsPGRH1li1WVRvKQ     3  2014-12-26      2
# 3hzhK9SJTgmqxRlXVGkxzA  Sm2k1ijcnK17Ro5paN2_qQ     0  2018-03-29      1
# WrCmzJ9n-_doiiwmTs-nPA  VPO8pBUwYz1u6GoG0d2U-Q     1  2014-12-22      1
# BzZbhsbdxsyN1D9FOALFnA  kd1VNJdd92T2eQ4hqvYQ5A     0  2018-04-26      0
#
#                         stars  \
# review_id
# BoguEYl3yC1bVU0KjdRqIw      4
# o8F3m8mQiuWYTbJEmFIyyw      5
# e96mj8MSNvJ3OWoA_90x9Q      3
# ...

# %%
b_list = [
    '2iTsRqUsPGRH1li1WVRvKQ',
    'FNe5PPA9pyj8FjcDefCBpg',
    'Lau3N654yNyWdIIybea1uA',
    'NG2mL-wQQfBdsXsyUbw8pA',
    'Sm2k1ijcnK17Ro5paN2_qQ',
    'UDE4VL0k8Zrko7RkJ4agGQ',
    'VPO8pBUwYz1u6GoG0d2U-Q',
    'kd1VNJdd92T2eQ4hqvYQ5A',
    'pomGBqfbxcqPv14c3XH-ZQ',
    'qJEtXdrOQeo9py0Wqr6LKQ'
]



b_r_f[b_r_f.index.isin(b_list)][["name", "stars", "price"]]
# Out:
#                                              name  stars  price
# business_id
# 2iTsRqUsPGRH1li1WVRvKQ             Carson Kitchen    4.5    2.0
# FNe5PPA9pyj8FjcDefCBpg                 Weera Thai    4.5    2.0
# Lau3N654yNyWdIIybea1uA                 Il Fornaio    3.5    2.0
# NG2mL-wQQfBdsXsyUbw8pA  Capriotti's Sandwich Shop    3.0    2.0
# Sm2k1ijcnK17Ro5paN2_qQ                Grand Pizza    4.0    2.0
# UDE4VL0k8Zrko7RkJ4agGQ            Little Dumpling    3.5    1.0
# VPO8pBUwYz1u6GoG0d2U-Q  Popeyes Louisiana Kitchen    2.0    1.0
# kd1VNJdd92T2eQ4hqvYQ5A            Above the Crust    4.0    1.0
# pomGBqfbxcqPv14c3XH-ZQ   Leticia's Mexican Cocina    4.0    2.0
# qJEtXdrOQeo9py0Wqr6LKQ     Blaze Fast Fired Pizza    4.0    1.0

# %%
b = pd.read_csv(path+"data\\business.csv", index_col="business_id")

# %%
[print(i) for i in b['categories'][11:500]]
# Out:
# Cajun/Creole, Southern, Restaurants
# Bars, Sports Bars, Dive Bars, Burgers, Nightlife, Sandwiches, Restaurants
# Restaurants, Pakistani, Indian, Middle Eastern
# Beauty & Spas, Barbers
# Delis, Restaurants, Sandwiches
# Nightlife, Bars, American (Traditional), Tapas/Small Plates, Poutineries, Supper Clubs, Restaurants, Tapas Bars
# Shopping, Fashion, Department Stores
# Financial Services, Check Cashing/Pay-day Loans, Title Loans
# American (Traditional), Food, Bakeries, Restaurants
# Home Services, Masonry/Concrete, Professional Services, Contractors
# Fast Food, Burgers, Restaurants
# Nightlife, Bars, American (Traditional), Sports Bars, Restaurants
# Food, Bakeries, Coffee & Tea
# Mexican, Restaurants
# Mexican, Restaurants
# Home Services, Home Automation, Security Systems
# Restaurants, Food, Canadian (New), Coffee & Tea
# Optometrists, Shopping, Eyewear & Opticians, Health & Medical
# Pizza, Restaurants
# Nightlife, Restaurants, Bars, Chicken Wings, American (Traditional)
# ...

# %%
b_full = pd.read_csv(path+"data\\business_full.csv", index_col="business_id")
b_full.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9237c1862bde> in <module>
# ----> 1 b_full = pd.read_csv(path+"data\\business_full.csv", index_col="business_id")
#       2 b_full.shape
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
b_full[b_full["city"] == "Las Vegas"].shape[0]/b_full.shape[0]
# Out:
# 0.15305446119421187

# %%
b_full[b_full["city"] == "Phoenix"].shape[0]/b_full.shape[0]
# Out:
# 0.09880006150811536

# %%
r_full = pd.read_csv(path+"data\\review.csv", index_col="review_id")
u_full = pd.read_csv(path+"data\\user.csv", index_col="user_id")

# %%
b = pd.read_csv(path+"data\\business_partial.csv", index_col="business_id")
b.shape
# Out:
# (30297, 44)

# %%
# subset to Las Vegas and Phoenix

b = b[b.city.isin(['Las Vegas', 'Phoenix'])]
print(b.shape)

r = r[r.business_id.isin(b.index)]
print(r.shape)

u = u[u.index.isin(r.user_id)]
print(u.shape)
# Out:
# (14776, 44)
# (1630574, 8)
# (580764, 21)

# %%
# map city column to reviews
r['city'] = r['business_id'].map(b['city'])

# %%
print(r[r["business_id"].isin(b[((b["cat_Restaurants"] == 1) | (b["cat_Food"] == 1))].index)].user_id.nunique()/u.shape[0])
print(r[r["business_id"].isin(b[b["cat_Shopping"] == 1].index)].user_id.nunique()/u.shape[0])
print(r[r["business_id"].isin(b[b["cat_Arts & Entertainment"] == 1].index)].user_id.nunique()/u.shape[0])
print(r[r["business_id"].isin(b[b["cat_Active Life"] == 1].index)].user_id.nunique()/u.shape[0])
print(r[r["business_id"].isin(b[b["cat_Tours"] == 1].index)].user_id.nunique()/u.shape[0])
# Out:
# 0.831329076871156
# 0.10314688926999607
# 0.20067703921041938
# 0.07534902301106818
# 0.013184357157124064

# %%
print(r[r["business_id"].isin(b[b["cat_Casinos"] == 1].index)].user_id.nunique()/u.shape[0])
print(r[r["business_id"].isin(b[b["cat_Coffee & Tea"] == 1].index)].user_id.nunique()/u.shape[0])
print(r[r["business_id"].isin(b[b["cat_Museums"] == 1].index)].user_id.nunique()/u.shape[0])
# Out:
# 0.12391780482261297
# 0.09921758235703315
# 0.010758242590794196

# %%
from collections import Counter

user_review_count = Counter([u for u in r.user_id])

# %%
len([k for k, v in user_review_count.items() if v == 1])/u.shape[0]
# Out:
# 0.6042833233464884

# %%
list(zip(random.sample(set(b.latitude[b.city == "Las Vegas"]), 5), random.sample(set(b.longitude[b.city == "Las Vegas"]), 5)))
# Out:
# [(36.09999570000001, -115.256773),
#  (36.173216, -115.285656607),
#  (36.068267, -115.117767641),
#  (36.038049998000005, -115.2236054),
#  (36.14552800000001, -115.182306)]

# %%
r[r.city == 'Phoenix']
# Out:
#                                    business_id  cool        date  funny  \
# review_id
# F1UHGw4-6OYyvFFb-E4LMg  VyVIneSU7XAWgMBllI6LnQ     0  2017-07-08      0
# QBZz9m3pL6r8Mvbdm2ZBYQ  Xg5qEQiB-7L6kGJ5F4K3bQ     0  2015-12-08      0
# 3zNW-BK3YlJnGBdCxpE46g  Jj8ubiwwuCR-rrhrrjcryw     0  2016-08-14      0
# ml9QmqSdQllqSO78RteQfA  ERCZtj8qxNxfXJrdXPdEsw     0  2016-04-29      2
# _03MY3VpWImsHHmDdll0Mw  CtI7MMRF-arzGJxA1nJccQ     0  2016-06-18      0
# tVUDpVAL1eb9BxUwRgJzyA  F9cXFXk60E2sz_YTSCFp_Q     0  2016-06-18      0
# oz66Z8p9Etq0WbcZVCmm7w  OX0T9dWI8b7meu-ljTo22A     0  2016-05-01      0
# RVO0dQJvBv33qNU1HBtBbw  nUaLFTfUqVKMFQonsWBnag     0  2016-06-11      0
# AxxtdHRnNQMFruSwUDc5jg  -YR7K3rw6VAQ1-MjslvsoQ     0  2016-06-18      0
# iJmz50_PKFNydHNK9uV86g  7m1Oa1VYV98UUuo_6i0EZg     0  2016-05-22      1
# oyhOp2Eu7A9rsnmoV0VFgA  SVMR0kRmdd-bbSNTTECJBA     0  2016-03-06      1
# EbfUnzwP3slrrjUpQbwVkQ  QVYyTgJFz7lcMv31ZmghGg     0  2016-06-09      0
# ...

# %%
r[r.user_id == 'CZHXSxJzu9dR179MbCCyew']
# Out:
#                                    business_id  cool        date  funny  \
# review_id
# tEWgm6GXXfBtw4deomEElA  q3oJ6bNRV3OoJrwc95GOwg     1  2016-11-12      0
# CpA70KUmDhTzqe6lGrUdCg  EvE23d1PSbfGWe7EA5HRBQ     0  2018-04-19      0
# ElN8VAUElS8A2a7_9SdXOg  B_WggEKFq-ZFNui8CHPYvA     0  2016-04-07      0
# 0BWI13sp-1AU_TG0bTy8Sw  0gWg-kqRLEQbhui8b_v2Xw     1  2016-05-20      0
# xB7WeenBmrkDqVqQSBx4rg  INzLc1Y0JNQzIHjPH2Nbeg     0  2016-10-04      0
# IaCBN9HsvIHgtm7wT6KFyw  _3olhuCXhoqjy4M2rBp1YA     0  2016-04-04      0
#
#                         stars  \
# review_id
# tEWgm6GXXfBtw4deomEElA      5
# CpA70KUmDhTzqe6lGrUdCg      5
# ElN8VAUElS8A2a7_9SdXOg      5
# 0BWI13sp-1AU_TG0bTy8Sw      5
# xB7WeenBmrkDqVqQSBx4rg      2
# IaCBN9HsvIHgtm7wT6KFyw      5
#
#                                                                      text  \
# review_id
# tEWgm6GXXfBtw4deomEElA  While in the area I stopped by to grab some fo...
# ...

# %%
# convert stars values into positive or negative
r['sentiment'] = r['stars'].apply(lambda x: 1 if x >3 else -1)

# %%
print(b[(b["city"] == "Las Vegas") & ((b["cat_Restaurants"] == 1) | (b["cat_Food"] == 1))].shape[0])
print(b[(b["city"] == "Las Vegas") & (b["cat_Shopping"] == 1)].shape[0])
print(b[(b["city"] == "Las Vegas") & (b["cat_Nightlife"] == 1)].shape[0])
print(b[(b["city"] == "Las Vegas") & (b["cat_Arts & Entertainment"] == 1)].shape[0])
print(b[(b["city"] == "Las Vegas") & (b["cat_Active Life"] == 1)].shape[0])
print(b[(b["city"] == "Las Vegas") & (b["cat_Hotels & Travel"] == 1)].shape[0])
#print(b[(b["city"] == "Las Vegas") & (b["cat_Landmark"] == 1)].shape[0])
print(b[(b["city"] == "Las Vegas") & (b["cat_Tours"] == 1)].shape[0])
# Out:
# 5077
# 2283
# 1314
# 870
# 789
# 730
# 137

# %%
print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & ((b["cat_Restaurants"] == 1) | (b["cat_Food"] == 1))].index)].shape[0])
print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Shopping"] == 1)].index)].shape[0])
print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Nightlife"] == 1)].index)].shape[0])
print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Arts & Entertainment"] == 1)].index)].shape[0])
print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Active Life"] == 1)].index)].shape[0])
print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Hotels & Travel"] == 1)].index)].shape[0])
print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Tours"] == 1)].index)].shape[0])
# Out:
# 947720
# 64479
# 268787
# 171283
# 44984
# 134783
# 6968

# %%
print(u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & ((b["cat_Restaurants"] == 1) | (b["cat_Food"] == 1))].index)].user_id)].shape[0])
print(u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Shopping"] == 1)].index)].user_id)].shape[0])
print(u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Nightlife"] == 1)].index)].user_id)].shape[0])
print(u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Arts & Entertainment"] == 1)].index)].user_id)].shape[0])
print(u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Active Life"] == 1)].index)].user_id)].shape[0])
print(u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Hotels & Travel"] == 1)].index)].user_id)].shape[0])
print(u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Tours"] == 1)].index)].user_id)].shape[0])
# Out:
# 360337
# 42054
# 156558
# 105701
# 33889
# 96379
# 6766

# %%
print(u[u.index.isin(r[r.business_id.isin(b[b["city"] == "Las Vegas"].index)].user_id)].shape[0])
# Out:
# 440055

# %%
print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & ((b["cat_Restaurants"] == 1) | (b["cat_Food"] == 1))].index)].shape[0] / 
      u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & ((b["cat_Restaurants"] == 1) | (b["cat_Food"] == 1))].index)].user_id)].shape[0])

print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Shopping"] == 1)].index)].shape[0] / 
      u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Shopping"] == 1)].index)].user_id)].shape[0])

print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Nightlife"] == 1)].index)].shape[0] / 
      u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Nightlife"] == 1)].index)].user_id)].shape[0])

print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Arts & Entertainment"] == 1)].index)].shape[0] / 
      u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Arts & Entertainment"] == 1)].index)].user_id)].shape[0])

print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Active Life"] == 1)].index)].shape[0] / 
      u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Active Life"] == 1)].index)].user_id)].shape[0])

print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Hotels & Travel"] == 1)].index)].shape[0] / 
      u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Hotels & Travel"] == 1)].index)].user_id)].shape[0])

print(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Tours"] == 1)].index)].shape[0] / 
      u[u.index.isin(r[r.business_id.isin(b[(b["city"] == "Las Vegas") & (b["cat_Tours"] == 1)].index)].user_id)].shape[0])
# Out:
# 2.630093495810866
# 1.533242973320017
# 1.7168525402726147
# 1.620448245522748
# 1.3273923692053469
# 1.3984685460525632
# 1.0298551581436595

# %%
[col for col in b.columns]
# Out:
# ['name',
#  'city',
#  'stars',
#  'price',
#  'review_count',
#  '1star_counts',
#  '2star_counts',
#  '3star_counts',
#  '4star_counts',
#  '5star_counts',
#  'text',
#  'text_friendly',
#  'text_reasonable',
#  'text_local',
#  'text_comfortable',
#  'text_easy',
#  'text_quick',
#  'categories',
#  'categories_clean',
#  'cat_Restaurants',
#  'cat_Food',
#  'cat_Shopping',
#  'cat_Active Life',
#  'cat_Arts & Entertainment',
#  'cat_Nightlife',
#  'cat_Hotels & Travel',
#  'cat_Tours',
#  'cat_Landmark',
#  'cat_Others',
#  'state',
#  'address',
#  'neighborhood',
#  'postal_code',
#  'latitude',
#  'longitude',
#  'monday',
#  'tuesday',
#  'wednesday',
#  'thursday',
#  'friday',
#  'saturday',
#  'sunday',
#  'las_vegas',
#  'word_count']

# %%
b.head()
# Out:
#                                               name       city  stars  price  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse  Las Vegas    4.0    4.0
# --DdmeR16TRb3LsjG0ejrQ    World Food Championships  Las Vegas    3.0    NaN
# --o5BoU7qYMALeVDK6mwVg             Nightlife Tours  Las Vegas    3.5    NaN
# --orEUqwTzz5QKbmyYbAWw        Advantage Rent-A-Car    Phoenix    2.5    NaN
# -0BxAGlIk5DJAGVkpqBXxg  The Coffee Bean & Tea Leaf  Las Vegas    3.0    2.0
#
#                         review_count  1star_counts  2star_counts  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw          1546          51.0         137.0
# --DdmeR16TRb3LsjG0ejrQ             5           0.0           2.0
# --o5BoU7qYMALeVDK6mwVg             6           2.0           0.0
# --orEUqwTzz5QKbmyYbAWw             3           2.0           0.0
# -0BxAGlIk5DJAGVkpqBXxg            43          11.0           6.0
#
#                         3star_counts  4star_counts  5star_counts  ...  \
# ...

# %%
# create a column multiplying average stars and review_counts
b['score_popularity'] = b.stars * b.review_count
b.head()
# Out:
#                                               name       city  stars  price  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw        Delmonico Steakhouse  Las Vegas    4.0    4.0
# --DdmeR16TRb3LsjG0ejrQ    World Food Championships  Las Vegas    3.0    NaN
# --o5BoU7qYMALeVDK6mwVg             Nightlife Tours  Las Vegas    3.5    NaN
# --orEUqwTzz5QKbmyYbAWw        Advantage Rent-A-Car    Phoenix    2.5    NaN
# -0BxAGlIk5DJAGVkpqBXxg  The Coffee Bean & Tea Leaf  Las Vegas    3.0    2.0
#
#                         review_count  1star_counts  2star_counts  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw          1546          51.0         137.0
# --DdmeR16TRb3LsjG0ejrQ             5           0.0           2.0
# --o5BoU7qYMALeVDK6mwVg             6           2.0           0.0
# --orEUqwTzz5QKbmyYbAWw             3           2.0           0.0
# -0BxAGlIk5DJAGVkpqBXxg            43          11.0           6.0
#
#                         3star_counts  4star_counts  5star_counts  ...  \
# ...

# %%
# create list of only necessary columns for popularity

'''
features = [
    'name',
    'categories',
    'popularity',
    'stars',
    'review_count',
    'price',
    'postal_code',
    'latitude',
    'longitude',
    'monday',
    'tuesday',
    'wednesday',
    'thursday',
    'friday',
    'saturday',
    'sunday'
]
'''
features = [
    'name',
#    'categories',
    'score_popularity',
    'stars',
    'price',
    'review_count',
    'latitude',
    'longitude'
]

# %%
# most popular restaurant/food
b_restaurants = b[features][(b.cat_Restaurants == 1) | (b.cat_Food == 1)].sort_values(by=["score_popularity"], ascending=False)
b_restaurants
# Out:
#                                                                name  \
# business_id
# 4JNXUYY8wbaaDmk3BPzlWw                                 Mon Ami Gabi
# RESDUcs7fIiihp38-d6_6g                             Bacchanal Buffet
# K7lWdNUhCbcnEvI0NhGewg                                 Wicked Spoon
# DkYS3arLOhA8si5uUEmHOw                             Earl of Sandwich
# f4x1YBxkLrZg652xt2KR5g                           Hash House A Go Go
# hihud--QRriCYZw1zZvW4g                     Gangnam Asian BBQ Dining
# iCQpiavjjPzJ5_3gPD5Ebg                                 Secret Pizza
# rcaPajgKOJC2vo_l3xa42A                 Bouchon at the Venezia Tower
# 2weQS-RnoOBhb1KsHKyoSQ                                   The Buffet
# ujHiaprwCQ5ewziu0Vi9rw                       The Buffet at Bellagio
# 3kdSl5mo9dWC4clrQjEDGg                                      Egg & I
# 7sPNbCx7vGAaH7SbNPZ6oA                                 Bachi Burger
# faPVqws-x-5k2CQKDNtHxw                Yardbird Southern Table & Bar
# ...

# %% [markdown]
# ### Evaluation

# %%
# test user set from LV & PH intersection
with open('u_lv_ph.pkl', 'rb') as f:
    u_lv_ph = pickle.load(f)

# %%
u_lv_ph
# Out:
# ['5H5cW9AcZCJNatsBmPSSMA',
#  '9eoGGgxkxCTOslJjN0xOSg',
#  'DBoxsHH0BNna7w0x1Gjcug',
#  '4AAbBOdBIIr5h0oEGWZ2Ig',
#  'ZotIehFSEUdJ62mrlpZiNw',
#  'Q3QEUfPspAySg_xpAoMhRw',
#  'UrHZox6yGePOOnYHWAGGGQ',
#  'oRmYV27nWVGTrKgGKR8wWA',
#  'eKqnE-38y3aVzgECIzQksg',
#  '5VInBSDMMdTLLcfIbufp5g',
#  'BPZEAoU0sB6CFGusTErUuA',
#  'iIZhsrl0WQInlvyhvukzMQ',
#  'TcJsjLTnnbKYP7MRQukAIg',
#  '9UMoH_L6TsrNWAkvxLeDYQ',
#  'KtUS6HMhgIPHXuwwkwReEw',
#  '1Xa4jl1eDgI3R32SaPEwsg',
#  'Z1m8zncYg1GoZxIkKUninA',
#  '7RdeSOlDzmNGOks-8CFR9Q',
#  'NvPaJD93VUlvkYdCY7MisQ',
#  'Ij7OcAO5FpoNKxS1RzNoWw',
#  'LZt80LbsfQ9kOz96H7c1bA',
#  'ZMBIjbnvatw6Z6JNPlS99Q',
#  'AfjVKIsLqzF71r2UccW2Fg',
#  'Um974FqapmEOc_Pe1joyqg',
#  'ZFJ74aq65K0ReL5zZqzfig',
#  'MSPyS_eBA1npoTDjA3Sq1w',
#  'ihERuh9d-HnpcoMVYY0WgA',
#  'v_vzBJwzw-QxZzH4t_52TA',
#  'Q4Qfu-3vYtL1LRm2X1b0Gg',
#  'z5SsgFBkXP5TnINhXumcFg',
#  'AgO_PZRL3rYOjIVa_gZGUg',
#  'vWQRmv8kVibtchTSBR1LWA',
#  'ZMgTn2Ryco0yg41VnVYYEg',
#  '3JAo9adFPShfeCB5PLHt0Q',
# ...

# %%
sample_size = 3000
test_idx = random.sample(range(len(u_lv_ph)), sample_size)
test_users = [u_lv_ph[i] for i in test_idx]

# %%
# save the list of test users
with open("u_test.pkl", "wb") as f:
    pickle.dump(test_users, f)

# %%
def rec_accuracy(recommendation_list, users, city="Las Vegas", k=100):
    """
    """
    accuracy = []
    top_items = recommendation_list.sort_values(by="score_popularity", ascending=False).iloc[:k,].index
    
    for user_id in users:
        known_positives = list(r.business_id[(r.user_id == user_id) & (r.city == city) & (r.sentiment == 1)])
        
        # skip if user has no known_positives
        if len(known_positives) == 0:
            continue
                
        true_positives = list(set(top_items) & set(known_positives))
        
        if len(known_positives) > k:
            acc = len(true_positives)/k
        else:
            acc = len(true_positives)/len(known_positives)
            
        accuracy.append(acc)
    
    return np.mean(accuracy)

# %%
rec_accuracy(b_restaurants, test_users)
# Out:
# 0.27228820805555926

# %%
# normalize the score
pmin = min(b_restaurants["popularity"])
pmax = max(b_restaurants["popularity"])

b_restaurants["popularity"] = b_restaurants["popularity"].apply(lambda x: (x - pmin)/(pmax - pmin))
b_restaurants
# Out:
#                                                                name  \
# business_id
# 4JNXUYY8wbaaDmk3BPzlWw                                 Mon Ami Gabi
# RESDUcs7fIiihp38-d6_6g                             Bacchanal Buffet
# K7lWdNUhCbcnEvI0NhGewg                                 Wicked Spoon
# DkYS3arLOhA8si5uUEmHOw                             Earl of Sandwich
# f4x1YBxkLrZg652xt2KR5g                           Hash House A Go Go
# hihud--QRriCYZw1zZvW4g                     Gangnam Asian BBQ Dining
# iCQpiavjjPzJ5_3gPD5Ebg                                 Secret Pizza
# rcaPajgKOJC2vo_l3xa42A                 Bouchon at the Venezia Tower
# 2weQS-RnoOBhb1KsHKyoSQ                                   The Buffet
# ujHiaprwCQ5ewziu0Vi9rw                       The Buffet at Bellagio
# 3kdSl5mo9dWC4clrQjEDGg                                      Egg & I
# 7sPNbCx7vGAaH7SbNPZ6oA                                 Bachi Burger
# faPVqws-x-5k2CQKDNtHxw                Yardbird Southern Table & Bar
# ...

# %%
b_restaurants.to_csv("reco_popularity_restaurants.csv")

# %%
# most popular Nightlife
b[features][b["cat_Nightlife"] == 1].sort_values(by=["popularity"], ascending=False)
# Out:
#                                                                name  \
# business_id
# 7sPNbCx7vGAaH7SbNPZ6oA                                 Bachi Burger
# XXW_OFaYQkkGOGniujZFHg  The Peppermill Restaurant & Fireside Lounge
# P7pxQFqr7yBKMMI2J51udw                      Holsteins Shakes & Buns
# MpmFFw0GE_2iRFPdsRpJbA                                 XS Nightclub
# t-o_Sraneime4DDhWrQRBA                               Wynn Las Vegas
# HhVmDybpU7L50Kb5A0jXTg              Guy Fieri's Vegas Kitchen & Bar
# awI4hHMfa7H0Xf0-ChU5hg                               The Oyster Bar
# I6EDDi4-Eq_XlFghcDCUhw        Joes Seafood Prime Steak & Stone Crab
# Cni2l-VKG_pdospJ6xliXQ                                   Burger Bar
# YJ8ljUhLsz6CtT_2ORNFmg                    Gordon Ramsay Pub & Grill
# pH0BLkL4cbxKzu471VZnuA                       SUSHISAMBA - Las Vegas
# JDZ6_yycNQFTpUZzLIKHUg                            El Dorado Cantina
# EAwh1OmG6t6p3nRaZOW_AA         Ellis Island Hotel, Casino & Brewery
# ...

# %%
# most popular Hotels & Travel
b[features][b["cat_Hotels & Travel"] == 1].sort_values(by=["popularity"], ascending=False)
# Out:
#                                                               name  \
# business_id
# 5LNZ67Yw9RD6nf4_UhXOjw               The Cosmopolitan of Las Vegas
# SMPbvZLSMMb7KU76YNYMGg                        ARIA Resort & Casino
# Wxxvi3LZbHNIDwJ-ZimtnA                      The Venetian Las Vegas
# FaHADZARwnY4yvlvpnsfGA              McCarran International Airport
# El4FC8jcawUVgw_0EIcbaQ                             MGM Grand Hotel
# na4Th5DrNauOv-c43QQFvA                              Bellagio Hotel
# t-o_Sraneime4DDhWrQRBA                              Wynn Las Vegas
# AV6weBrZFFBfRGCbcRGO4g            Luxor Hotel and Casino Las Vegas
# uGupeWqih0yIcCg8anM1PA                       The Palazzo Las Vegas
# eAc9Vd6loOgRQolMXQt6FA                Mandalay Bay Resort & Casino
# BLIJ-p5wYuAhw6Pp6mh6mw  Planet Hollywood Las Vegas Resort & Casino
# u_vPjx925UPEG9DFOAAvFQ           Flamingo Las Vegas Hotel & Casino
# VyjyHoBg3KC5BSFRlD0ZPQ     Caesars Palace Las Vegas Hotel & Casino
# ...

# %%
# most popular Tours
reco_tours = b[features][(b["cat_Tours"] == 1) & (b["cat_Museums"] == 0)].sort_values(by=["popularity"], ascending=False)

# %%
reco_tours.drop("eStn1HCGNcKiLXc0pfvZxg", inplace=True)

# %%
reco_tours.to_csv("reco_tours.csv")

# %%
# most popular casinos
b["cat_Casinos"] = b["categories_clean"].apply(lambda x: 1 if 'Casinos' in x else 0)

# %%
reco_casinos = b[features][b["cat_Casinos"] == 1].sort_values(by=["popularity"], ascending=False)

# %%
reco_casinos.to_csv("reco_casinos.csv")

# %%
# most popular museums
b["cat_Museums"] = b["categories_clean"].apply(lambda x: 1 if 'Museums' in x else 0)

# %%
reco_museums = b[features][b["cat_Museums"] == 1].sort_values(by=["popularity"], ascending=False)

# %%
reco_museums.to_csv("reco_museums.csv")

# %%
# most popular coffee/tea
b["cat_Coffee & Tea"] = b["categories_clean"].apply(lambda x: 1 if 'Coffee & Tea' in x else 0)

# %%
reco_coffee = b[features][(b["cat_Coffee & Tea"] == 1) & (b["cat_Restaurants"] == 0)].sort_values(by=["popularity"], ascending=False)

# %%
reco_coffee.to_csv("reco_coffee.csv")

# %%
# most popular shopping
reco_shopping = b[features][(b.cat_Shopping == 1) & (b.cat_Museums == 0) & (b["cat_Active Life"] == 0)].sort_values(by=["popularity"], ascending=False)

# %%
reco_shopping.to_csv("reco_shopping.csv")

# %%
# most popular Active Life
reco_active = b[features][(b["cat_Active Life"] == 1) & (b["cat_Hotels & Travel"] == 0) & (b["cat_Museums"] == 0) & (b["cat_Arts & Entertainment"] == 0) & (b["cat_Restaurants"] == 0)].sort_values(by=["popularity"], ascending=False)

# %%
reco_active.to_csv("reco_active.csv")

# %%
# most popular Arts & Entertainment
reco_arts = b[features][(b["cat_Arts & Entertainment"] == 1) & (b["cat_Hotels & Travel"] == 0) & (b["cat_Nightlife"] == 0) & (b["cat_Museums"] == 0)].sort_values(by=["popularity"], ascending=False)

# %%
reco_arts.to_csv("reco_arts.csv")
