# %%
# %matplotlib inline

# %%
import os, sys, time
import json, csv
import numpy as np
import numpy.ma as ma
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
business = pd.read_csv("business.csv")
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['price'] = business.attributes.str.extract('((?<=\'RestaurantsPriceRange2\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
print("{} businesses missing price".format(business.price.isnull().sum()))
print("{}% missing price".format(business.price.isnull().sum()/business.shape[0]*100))
# Out:
# 81473 businesses missing price
# 43.200436919716% missing price

# %%
business['agesallowed'] = business.attributes.str.extract('((?<=\'AgesAllowed\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['alcohol'] = business.attributes.str.extract('((?<=\'Alcohol\': \')\S*(?=\',|\'}))', expand=True)
siness.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['ambience'] = business.attributes.str.extract('((?<=\'Ambience\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['byob'] = business.attributes.str.extract('((?<=\'BYOB\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['byobcorkage'] = business.attributes.str.extract('((?<=\'BYOBCorkage\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['bestnights'] = business.attributes.str.extract('((?<=\'BestNights\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['bikeparking'] = business.attributes.str.extract('((?<=\'BikeParking\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['businessacceptsbitcoin'] = business.attributes.str.extract('((?<=\'BusinessAcceptsBitcoin\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['businessacceptscreditcards'] = business.attributes.str.extract('((?<=\'BusinessAcceptsCreditCards\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['businessparking'] = business.attributes.str.extract('((?<=\'BusinessParking\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['byappointmentonly'] = business.attributes.str.extract('((?<=\'ByAppointmentOnly\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['coatcheck'] = business.attributes.str.extract('((?<=\'CoatCheck\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['corkage'] = business.attributes.str.extract('((?<=\'Corkage\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['dietaryrestrictions'] = business.attributes.str.extract('((?<=\'DietaryRestrictions\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['dogsallowed'] = business.attributes.str.extract('((?<=\'DogsAllowed\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['drivethru'] = business.attributes.str.extract('((?<=\'DriveThru\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['goodfordancing'] = business.attributes.str.extract('((?<=\'GoodForDancing\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['goodforkids'] = business.attributes.str.extract('((?<=\'GoodForKids\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['goodformeal'] = business.attributes.str.extract('((?<=\'GoodForMeal\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['happyhour'] = business.attributes.str.extract('((?<=\'HappyHour\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['hastv'] = business.attributes.str.extract('((?<=\'HasTV\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['music'] = business.attributes.str.extract('((?<=\'Music\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['noiselevel'] = business.attributes.str.extract('((?<=\'NoiseLevel\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['open24hours'] = business.attributes.str.extract('((?<=\'Open24Hours\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['outdoorseating'] = business.attributes.str.extract('((?<=\'OutdoorSeating\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['restaurantsattire'] = business.attributes.str.extract('((?<=\'RestaurantsAttire\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['restaurantscounterservice'] = business.attributes.str.extract('((?<=\'RestaurantsCounterService\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['restaurantsdelivery'] = business.attributes.str.extract('((?<=\'RestaurantsDelivery\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['restaurantsgoodforgroups'] = business.attributes.str.extract('((?<=\'RestaurantsGoodForGroups\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['restaurantsreservations'] = business.attributes.str.extract('((?<=\'RestaurantsReservations\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['restaurantstableservice'] = business.attributes.str.extract('((?<=\'RestaurantsTableService\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['restaurantstakeout'] = business.attributes.str.extract('((?<=\'RestaurantsTakeOut\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['smoking'] = business.attributes.str.extract('((?<=\'Smoking\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['wheelchairaccessible'] = business.attributes.str.extract('((?<=\'WheelchairAccessible\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['wifi'] = business.attributes.str.extract('((?<=\'WiFi\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %% [markdown]
# #### Unnest 'HOURS'

# %%
business['monday'] = business.hours.str.extract('((?<=\'Monday\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['tuesday'] = business.hours.str.extract('((?<=\'Tuesday\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['wednesday'] = business.hours.str.extract('((?<=\'Wednesday\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['thursday'] = business.hours.str.extract('((?<=\'Thursday\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['friday'] = business.hours.str.extract('((?<=\'Friday\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['saturday'] = business.hours.str.extract('((?<=\'Saturday\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business['sunday'] = business.hours.str.extract('((?<=\'Sunday\': \')\S*(?=\',|\'}))', expand=True)
business.head()
# Out:
#                address                                         attributes  \
# 0    1314 44 Avenue NE  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 1                  NaN  {'Alcohol': 'none', 'BikeParking': 'False', 'B...
# 2  1335 rue Beaubien E  {'Alcohol': 'beer_and_wine', 'Ambience': "{'ro...
# 3      211 W Monroe St                                                NaN
# 4  2005 Alyth Place SE             {'BusinessAcceptsCreditCards': 'True'}
#
#               business_id                                         categories  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Ho...
# 1  AjEbIBw6ZFfln7ePHha9PA  Chicken Wings, Burgers, Caterers, Street Vendo...
# 2  O8S5hYJ1SMc8fA4QBtVujA  Breakfast & Brunch, Restaurants, French, Sandw...
# 3  bFzdJJ3wp3PZssNEsyU23g                      Insurance, Financial Services
# 4  8USyCYqpScwiNEb58Bt6CA  Home & Garden, Nurseries & Gardening, Shopping...
#
# ...

# %%
business.to_csv('business_attributes.csv', index=False)
